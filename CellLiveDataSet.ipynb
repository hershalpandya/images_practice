# %%
# %matplotlib inline
import pylab as plt
import plotly as pltly
from skimage import data, segmentation
from skimage import filters
import numpy as np
from skimage import io,color
from skimage import feature

# %%
rootdir="/Users/hershalpandya/data/temp_delete/images/livecell_train_val_images/A172/"
image = io.imread(rootdir+'A172_Phase_A7_1_00d00h00m_1.tif')

# %%
plt.imshow(image,cmap='gray')

# %% [markdown]
# ### HOG or simple contours and then K-means (SLIC)

# %%
image_hog,hog_visualize= feature.hog(image, pixels_per_cell=(8,8),visualize=True)

# %%
plt.figure()
plt.imshow(hog_visualize, cmap='binary')
plt.title("HOG")

plt.figure()
qcs = plt.contour(image, origin='image')
plt.title('Contour plot of the same raw image')
plt.show()

# %%
hog_visualize.shape
# Out:
# (520, 704)

# %%
image.shape
# Out:
# (520, 704)

# %%
p = qcs.collections[0].get_paths()
print (p)
v = p.vertices
x = v[:,0]
y = v[:,1]
# Out:
# []
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-167989650f51> in <module>
#       1 p = qcs.collections[0].get_paths()
#       2 print (p)
# ----> 3 v = p.vertices
#       4 x = v[:,0]
#       5 y = v[:,1]
#
# AttributeError: 'list' object has no attribute 'vertices'
